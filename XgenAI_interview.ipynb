# %% [markdown]
# <a href="https://colab.research.google.com/github/Banafshehkh/Interview_Preparation/blob/main/XgenAI_interview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import string

def unique_letters(sample):
  all_alpha = "abcdefghijklmnopqrstuvwxyz"
  sample = ''.join(sorted(sample))
  lst = []
  sample_set = set(sample)
  all_alpha_set = set(all_alpha)

  result = list(all_alpha_set - sample_set)
  result.sort()

  return result



sample = "abcdefgpqrstuvwxyz"
unique_letters(sample)
# Out:
# ['h', 'i', 'j', 'k', 'l', 'm', 'n', 'o']

# %%
import pandas as pd

# %%
table_MN = pd.read_html('https://en.wikipedia.org/wiki/List_of_automobile_sales_by_model')
df = table_MN[2]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Image       0 non-null      float64
#  1   Automobile  47 non-null     object
#  2   Production  47 non-null     object
#  3   Sales       47 non-null     object
# dtypes: float64(1), object(3)
# memory usage: 1.7+ KB

# %%
df.head(3)
# Out:
#    Image Automobile Production  \
# 0    NaN  BMC ADO16  1962–1974
# 1    NaN  BMC ADO17  1964–1975
# 2    NaN        NaN        NaN
#
#                                                Sales
# 0  2,167,783 made under the brand names of Austin...
# 1  387,283 made under the brand names of Austin, ...
# 2                                                NaN

# %%
df.isnull().sum()
# Out:
# Image         51
# Automobile     4
# Production     4
# Sales          4
# dtype: int64

# %%
# df = df.drop(columns = "Image")

# %%
df.head(2)
# Out:
#   Automobile Production                                              Sales
# 0  BMC ADO16  1962–1974  2,167,783 made under the brand names of Austin...
# 1  BMC ADO17  1964–1975  387,283 made under the brand names of Austin, ...

# %%
df1 = df.copy()
df1 = df1.dropna(axis = 0)

# %%
df1.isnull().sum()
# Out:
# Automobile    0
# Production    0
# Sales         0
# dtype: int64

# %%
df1
# Out:
#               Automobile           Production  \
# 0              BMC ADO16            1962–1974
# 1              BMC ADO17            1964–1975
# 3                BMW 326       1936–1941 1946
# 4                BMW 328            1936–1940
# 5                BMW 327  1937–1941 1946–1955
# 6                BMW 507            1956–1959
# 7                BMW 503            1956–1959
# 8            BMW 3200 CS            1962–1965
# 9          BMW New Class              1962–76
# 10  BMW 2000C and 2000CS              1965–69
# 11                BMW CS              1968–75
# 12                BMW i3         2013–present
# 13                BMW i8            2014–2020
# 14                BMW M1              1978–81
# 15                BMW Z1              1989–91
# 16                BMW Z8            1999–2003
# 17          BMW 3 Series         1975–present
# 18          BMW 5 Series         1972–present
# 19          BMW 8 Series              1989–99
# ...
