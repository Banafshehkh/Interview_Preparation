# %% [markdown]
# <a href="https://colab.research.google.com/github/Banafshehkh/Interview_Preparation/blob/main/Product_Recommendation_System_for_e_commerce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn
from sklearn.decomposition import TruncatedSVD

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv("/content/drive/MyDrive/interview/ratings_Beauty.csv")
data.head(4)
# Out:
#            UserId   ProductId  Rating   Timestamp
# 0  A39HTATAQ9V7YF  0205616461     5.0  1369699200
# 1  A3JM6GV9MNOF9X  0558925278     3.0  1355443200
# 2  A1Z513UWSAAO0F  0558925278     5.0  1404691200
# 3  A1WMRR494NWEWV  0733001998     4.0  1382572800

# %%
data.isnull().sum()
# Out:
# UserId       0
# ProductId    0
# Rating       0
# Timestamp    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2023070 entries, 0 to 2023069
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   UserId     object
#  1   ProductId  object
#  2   Rating     float64
#  3   Timestamp  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 61.7+ MB

# %%
popular_products = pd.DataFrame(data.groupby('ProductId')['Rating'].count())
most_popular = popular_products.sort_values('Rating', ascending=False)

most_popular.head()
# Out:
#             Rating
# ProductId
# B001MA0QY2    7533
# B0009V1YR8    2869
# B0043OYFKU    2477
# B0000YUXI0    2143
# B003V265QW    2088

# %%
most_popular.head(10).plot(kind = "bar", color = "r")
# Out:
# <Axes: xlabel='ProductId'>

# %%
amazon_ratings1 = data.head(10000)

# %%
rating_matrix = amazon_ratings1.pivot_table(values = "Rating", index = "UserId", columns= "ProductId", fill_value = 0)
rating_matrix
# Out:
# ProductId              0205616461  0558925278  0733001998  0737104473  \
# UserId
# A00205921JHJK5X9LNP42           0           0           0           0
# A024581134CV80ZBLIZTZ           0           0           0           0
# A03056581JJIOL5FSKJY7           0           0           0           0
# A03099101ZRK4K607JVHH           0           0           0           0
# A0505229A7NSH3FRXRR4            0           0           0           0
# ...                           ...         ...         ...         ...
# AZZHJZP4GQPPZ                   0           0           0           0
# AZZNK89PXD006                   0           0           0           0
# AZZOFVMQC0BJG                   0           0           0           0
# AZZQXL8VDCFTV                   0           0           0           0
# AZZTJQ7CQZUD8                   0           0           0           0
#
# ProductId              0762451459  1304139212  1304139220  130414089X  \
# UserId
# ...

# %%
rating_matrix.shape
# Out:
# (9697, 886)

# %%
X = rating_matrix.T
X.head()
# Out:
# UserId      A00205921JHJK5X9LNP42  A024581134CV80ZBLIZTZ  \
# ProductId
# 0205616461                      0                      0
# 0558925278                      0                      0
# 0733001998                      0                      0
# 0737104473                      0                      0
# 0762451459                      0                      0
#
# UserId      A03056581JJIOL5FSKJY7  A03099101ZRK4K607JVHH  \
# ProductId
# 0205616461                      0                      0
# 0558925278                      0                      0
# 0733001998                      0                      0
# 0737104473                      0                      0
# 0762451459                      0                      0
#
# UserId      A0505229A7NSH3FRXRR4  A05492663T95KW63BR75K  \
# ProductId
# 0205616461                     0                      0
# 0558925278                     0                      0
# 0733001998                     0                      0
# ...

# %% [markdown]
# # **Dimentionality Reduction**

# %%
SVD = TruncatedSVD(n_components=10)
decomposed_matrix = SVD.fit_transform(X)
decomposed_matrix.shape
# Out:
# (886, 10)

# %%
correlation_matrix = np.corrcoef(decomposed_matrix)
correlation_matrix.shape
# Out:
# (886, 886)

# %%
i = "6117036094"

product_names = list(X.index)
product_ID = product_names.index(i)


correlation_product_ID = correlation_matrix[product_ID]
correlation_product_ID.shape
# Out:
# (886,)

# %%
correlation_product_ID = correlation_matrix[product_ID]
correlation_product_ID.shape
# Out:
# (886,)

# %%
Recommend = list(X.index[correlation_product_ID > 0.90])

# Removes the item already bought by the customer
Recommend.remove(i)

Recommend[0:9]
# Out:
# ['0733001998',
#  '4057362886',
#  '6022600685',
#  '8430539387',
#  '8982641262',
#  '9502737628',
#  '9509369934',
#  '9744434139',
#  '9788072119']
